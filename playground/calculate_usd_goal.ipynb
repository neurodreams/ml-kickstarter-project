# %%
import pandas as pd
from pathlib import Path
from datetime import timedelta

# %%
df = pd.read_csv("../data/raw_data.csv")
# Out:
# C:\Users\metal\AppData\Local\Temp\ipykernel_61756\3407229622.py:1: DtypeWarning: Columns (28,30,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw_data.csv")

# %%
def get_fx_date(launched_date):
    """Return the date to use for FX rate lookup.

    Mon–Fri: use the same day.
    Sat:     use Friday (one day earlier).
    Sun:     use Friday (two days earlier).
    """
    date = pd.to_datetime(launched_date)

    weekday = date.weekday() # 0=Mon ... 4=Fri, 5=Sat, 6=Sun

    if weekday == 5: # Saturday
        date = date - timedelta(days=1)
    elif weekday == 6: # Sunday
        date = date - timedelta(days=2)
        
    return date.normalize()

# %%
def add_fx_mean(df: pd.DataFrame, fx_folder: str = "../data/fx_rates") -> pd.DataFrame:
    """Add fx_daily_mean for each row using daily FX CSVs and weekend logic.

    - launched_at is assumed to be epoch seconds.
    - For non-USD rows, FX rate is looked up from <currency>-USD_daily.csv
      using an FX date where Sat/Sun are mapped back to Friday.
    - For USD rows, fx_daily_mean is set to 1.0.

    Parameters
    ----------
    df : pd.DataFrame
        Project-level dataset with at least columns: 'currency', 'launched_at'.
    fx_folder : str, optional
        Folder path where the FX CSV files are stored.

    Returns
    -------
    pd.DataFrame
        Copy of the input DataFrame with new columns:
        - launched_date
        - fx_date
        - fx_daily_mean
    """
    
    df = df.copy()
    df["launched_date"] = pd.to_datetime(df["launched_at"], unit="s").dt.floor("D")
    
    # Luodaan fx_date: viikonloput -> perjantai
    df["fx_date"] = df["launched_date"].apply(get_fx_date)
    
    # Separate currencies to USD & others
    df_usd = df[df["currency"] == "USD"].copy()
    df_non_usd = df[df["currency"] != "USD"].copy()

    # USD - USD uses static 1.0 fx-rate
    df_usd["fx_daily_mean"] = 1.0
    
    # Get list of non-USD currencies
    currency_list = set(df_non_usd["currency"])

    merged_parts = []

    for currency in currency_list:
        df_sub = df_non_usd[df_non_usd["currency"] == currency].copy()

        # Get fx-rates from csv
        fx_path = f"{fx_folder}/{currency}-USD_daily.csv"
        fx = pd.read_csv(fx_path)

        fx["fx_date"] = pd.to_datetime(fx["timestamp"]).dt.floor("D")

        df_sub = df_sub.merge(
            fx[["fx_date", "fx_daily_mean"]],
            on = "fx_date",
            how = "left",
        )
        
        merged_parts.append(df_sub)

    df_final = pd.concat([df_usd] + merged_parts, ignore_index=True)

    return df_final

# %%
df.head(5)
# Out:
#    collected_at  backers_count  \
# 0        202505         185341
# 1        202505          78471
# 2        202505          55106
# 3        202505          62642
# 4        202505          83193
#
#                                                blurb  category_id  \
# 0  A Year of Sanderson: Enjoy books and swag boxe...         47.0
# 1  Color e-paper smartwatch with up to 7 days of ...         28.0
# 2  Beginning with The Stormlight Archive and expa...         34.0
# 3  The COOLEST is a portable party disguised as a...         28.0
# 4  Euro-inspired dungeon crawling sequel to the 2...         34.0
#
#     category_name  category_parent_id category_parent_name  \
# 0         Fiction                  18           Publishing
# 1  Product Design                   7               Design
# 2  Tabletop Games                  12                Games
# 3  Product Design                   7               Design
# 4  Tabletop Games                  12                Games
#
#                                         category_url  \
# 0  http://www.kickstarter.com/discover/categories...
# 1  http://www.kickstarter.com/discover/categories...
# 2  http://www.kickstarter.com/discover/categories...
# 3  http://www.kickstarter.com/discover/categories...
# 4  http://www.kickstarter.com/discover/categories...
#
#    converted_pledged_amount country  ...  profile_state_changed_at  \
# 0                41754153.0      US  ...              1.648768e+09
# 1                20338986.0      US  ...              1.427590e+09
# 2                15149874.0      US  ...              1.726001e+09
# 3                13285226.0      US  ...              1.428101e+09
# 4                12969608.0      US  ...              1.588367e+09
#
#                                          project_url spotlight staff_pick  \
# 0  https://www.kickstarter.com/projects/dragonste...      True       True
# 1  https://www.kickstarter.com/projects/getpebble...      True       True
# 2  https://www.kickstarter.com/projects/brotherwi...      True       True
# 3  https://www.kickstarter.com/projects/ryangrepp...      True      False
# 4  https://www.kickstarter.com/projects/frosthave...      True       True
#
#         state  state_changed_at  static_usd_rate  usd_exchange_rate  \
# 0  successful        1648767600              1.0                1.0
# 1  successful        1427508015              1.0                1.0
# 2  successful        1724986800              1.0                1.0
# 3  successful        1409360410              1.0                1.0
# 4  successful        1588366800              1.0                1.0
#
#    usd_pledged  usd_type
# 0  41754153.24  domestic
# 1  20338986.27  domestic
# 2  15149874.00  domestic
# 3  13285226.36  domestic
# 4  12969608.00  domestic
#
# [5 rows x 43 columns]

# %%
df = add_fx_mean(df)

# %%
df = df[df["currency"]!= "USD"]
df.head(5)
# Out:
#         collected_at  backers_count  \
# 435023        202505          12375
# 435024        202505          19909
# 435025        202505           3299
# 435026        202505           4634
# 435027        202505            553
#
#                                                     blurb  category_id  \
# 435023  UNOBRUSHTM is the world’s smartest toothbrush ...         28.0
# 435024  A sustainable alternative to the cotton swabs,...         28.0
# 435025  A CO2 monitor designed to improve the indoor a...         28.0
# 435026  Great quality ski and snowboard goggles from C...         28.0
# 435027  Watches made from recycled Mustangs, powered b...         28.0
#
#          category_name  category_parent_id category_parent_name  \
# 435023  Product Design                   7               Design
# 435024  Product Design                   7               Design
# 435025  Product Design                   7               Design
# 435026  Product Design                   7               Design
# 435027  Product Design                   7               Design
#
#                                              category_url  \
# 435023  http://www.kickstarter.com/discover/categories...
# 435024  http://www.kickstarter.com/discover/categories...
# 435025  http://www.kickstarter.com/discover/categories...
# 435026  http://www.kickstarter.com/discover/categories...
# 435027  http://www.kickstarter.com/discover/categories...
#
#         converted_pledged_amount country  ...  staff_pick       state  \
# 435023                 1105454.0      DK  ...       False  successful
# 435024                  718818.0      DK  ...       False  successful
# 435025                  458167.0      DK  ...        True  successful
# 435026                  465045.0      DK  ...        True  successful
# 435027                  465131.0      DK  ...        True  successful
#
#        state_changed_at static_usd_rate usd_exchange_rate   usd_pledged  \
# 435023       1542906019        0.154326          0.152685  1.117333e+06
# 435024       1558021953        0.151544          0.150091  7.257768e+05
# 435025       1651759112        0.148530          0.142687  4.769279e+05
# 435026       1543075086        0.154021          0.151925  4.714604e+05
# 435027       1451948340        0.143288          0.145655  4.575713e+05
#
#              usd_type  launched_date    fx_date  fx_daily_mean
# 435023       domestic     2018-10-22 2018-10-22        0.15411
# 435024       domestic     2019-04-16 2019-04-16        0.15136
# 435025       domestic     2022-04-05 2022-04-05        0.14715
# 435026  international     2018-10-10 2018-10-10        0.15436
# 435027       domestic     2015-11-20 2015-11-20        0.14330
#
# [5 rows x 46 columns]

# %%
df[df["fx_daily_mean"].isna()]
df
# Out:
#         collected_at  backers_count  \
# 435023        202505          12375
# 435024        202505          19909
# 435025        202505           3299
# 435026        202505           4634
# 435027        202505            553
# ...              ...            ...
# 629142        202504              0
# 629143        202504              0
# 629144        202504              0
# 629145        202504              0
# 629146        202503              0
#
#                                                     blurb  category_id  \
# 435023  UNOBRUSHTM is the world’s smartest toothbrush ...         28.0
# 435024  A sustainable alternative to the cotton swabs,...         28.0
# 435025  A CO2 monitor designed to improve the indoor a...         28.0
# 435026  Great quality ski and snowboard goggles from C...         28.0
# 435027  Watches made from recycled Mustangs, powered b...         28.0
# ...                                                   ...          ...
# 629142     Let us bring Spirit War to the global audience         34.0
# 629143  A cooperative board game for 1-4 players from ...         34.0
# 629144  Enter ARMONS, your AR Partners that you can nu...        272.0
# 629145  Chain-K not just stores your memory, but can b...          NaN
# 629146  A quick, dirty and clever two-player game. Blu...         34.0
#
#          category_name  category_parent_id category_parent_name  \
# 435023  Product Design                   7               Design
# 435024  Product Design                   7               Design
# 435025  Product Design                   7               Design
# 435026  Product Design                   7               Design
# 435027  Product Design                   7               Design
# ...                ...                 ...                  ...
# 629142  Tabletop Games                  12                Games
# 629143  Tabletop Games                  12                Games
# 629144    Mobile Games                  12                Games
# 629145             NaN                  16           Technology
# 629146  Tabletop Games                  12                Games
#
#                                              category_url  \
# 435023  http://www.kickstarter.com/discover/categories...
# 435024  http://www.kickstarter.com/discover/categories...
# 435025  http://www.kickstarter.com/discover/categories...
# 435026  http://www.kickstarter.com/discover/categories...
# 435027  http://www.kickstarter.com/discover/categories...
# ...                                                   ...
# 629142  http://www.kickstarter.com/discover/categories...
# 629143  http://www.kickstarter.com/discover/categories...
# 629144  http://www.kickstarter.com/discover/categories...
# 629145  http://www.kickstarter.com/discover/categories...
# 629146  http://www.kickstarter.com/discover/categories...
#
#         converted_pledged_amount country  ...  staff_pick       state  \
# 435023                 1105454.0      DK  ...       False  successful
# 435024                  718818.0      DK  ...       False  successful
# 435025                  458167.0      DK  ...        True  successful
# 435026                  465045.0      DK  ...        True  successful
# 435027                  465131.0      DK  ...        True  successful
# ...                          ...     ...  ...         ...         ...
# 629142                       NaN      SG  ...       False   submitted
# 629143                       NaN      SG  ...       False   submitted
# 629144                       NaN      SG  ...       False   submitted
# 629145                       NaN      SG  ...       False   submitted
# 629146                       NaN      SG  ...       False   submitted
#
#        state_changed_at static_usd_rate usd_exchange_rate   usd_pledged  \
# 435023       1542906019        0.154326          0.152685  1.117333e+06
# 435024       1558021953        0.151544          0.150091  7.257768e+05
# 435025       1651759112        0.148530          0.142687  4.769279e+05
# 435026       1543075086        0.154021          0.151925  4.714604e+05
# 435027       1451948340        0.143288          0.145655  4.575713e+05
# ...                 ...             ...               ...           ...
# 629142       1704701583        0.000000               NaN           NaN
# 629143       1609738886        0.000000               NaN           NaN
# 629144       1647189291        0.000000               NaN           NaN
# 629145       1610536265        0.000000               NaN           NaN
# 629146       1699450130        0.000000               NaN           NaN
#
#              usd_type  launched_date    fx_date  fx_daily_mean
# 435023       domestic     2018-10-22 2018-10-22        0.15411
# 435024       domestic     2019-04-16 2019-04-16        0.15136
# 435025       domestic     2022-04-05 2022-04-05        0.14715
# 435026  international     2018-10-10 2018-10-10        0.15436
# 435027       domestic     2015-11-20 2015-11-20        0.14330
# ...               ...            ...        ...            ...
# 629142       domestic     1970-01-01 1970-01-01            NaN
# 629143       domestic     1970-01-01 1970-01-01            NaN
# 629144       domestic     1970-01-01 1970-01-01            NaN
# 629145       domestic     1970-01-01 1970-01-01            NaN
# 629146       domestic     1970-01-01 1970-01-01            NaN
#
# [194124 rows x 46 columns]

# %%
df["usd_goal_fx"] = (df["goal"] * df["fx_daily_mean"]).round(0)

# %%
df = df[["country", "currency","goal", "fx_daily_mean", "usd_goal_fx"]]
df
# Out:
#        country currency       goal  fx_daily_mean  usd_goal_fx
# 435023      DK      DKK   100223.0        0.15411      15445.0
# 435024      DK      DKK    89000.0        0.15136      13471.0
# 435025      DK      DKK    50000.0        0.14715       7358.0
# 435026      DK      DKK    50000.0        0.15436       7718.0
# 435027      DK      DKK  1400000.0        0.14330     200620.0
# ...        ...      ...        ...            ...          ...
# 629142      SG      SGD        0.0            NaN          NaN
# 629143      SG      SGD        0.0            NaN          NaN
# 629144      SG      SGD        0.0            NaN          NaN
# 629145      SG      SGD        0.0            NaN          NaN
# 629146      SG      SGD        0.0            NaN          NaN
#
# [194124 rows x 5 columns]
