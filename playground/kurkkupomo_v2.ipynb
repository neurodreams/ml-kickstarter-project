# %%
import pandas as pd

# %%
df = pd.read_csv("../data/feature_processed_data.csv")

# %%
df.head(5)
# Out:
#                                                blurb   category_name  \
# 0  A Year of Sanderson: Enjoy books and swag boxe...         Fiction
# 1  Color e-paper smartwatch with up to 7 days of ...  Product Design
# 2  Beginning with The Stormlight Archive and expa...  Tabletop Games
# 3  The COOLEST is a portable party disguised as a...  Product Design
# 4  Euro-inspired dungeon crawling sequel to the 2...  Tabletop Games
#
#    category_parent_id category_parent_name country  creator_id currency  \
# 0                  18           Publishing      US    74501917      USD
# 1                   7               Design      US   597507018      USD
# 2                  12                Games      US   237961243      USD
# 3                   7               Design      US   203090294      USD
# 4                  12                Games      US  1350948450      USD
#
#      deadline       goal          id  ... blurb_is_english name_missing  \
# ...

# %%
df.dtypes
# Out:
# blurb                                object
# category_name                        object
# category_parent_id                    int64
# category_parent_name                 object
# country                              object
# creator_id                            int64
# currency                             object
# deadline                             object
# goal                                float64
# id                                    int64
# name                                 object
# state                                object
# launched_date                        object
# fx_date                              object
# fx_daily_mean                       float64
# usd_goal_fx                         float64
# blurb_missing                         int64
# blurb_len                             int64
# blurb_lang                           object
# blurb_is_english                      int64
# name_missing                          int64
# ...

# %%
name = df["name"]
name.head(20)
# Out:
# 0     Surprise! Four Secret Novels by Brandon Sanderson
# 1      Pebble Time - Awesome Smartwatch, No Compromises
# 2                      Brandon Sanderson's Cosmere® RPG
# 3     COOLEST COOLER: 21st Century Cooler that's Act...
# 4                                            Frosthaven
# 5                Pebble 2, Time 2 + All-New Pebble Core
# 6                            Kingdom Death: Monster 1.5
# 7          EcoFlow DELTA Pro: The Portable Home Battery
# 8                          Travel Tripod by Peak Design
# 9     Critical Role: The Legend of Vox Machina Anima...
# 10    Valerion VisionMaster: Cinematic-Grade RGB Las...
# 11         Pebble: E-Paper Watch for iPhone and Android
# 12                 Avatar Legends: The Roleplaying Game
# 13    The World's Best TRAVEL JACKET with 15 Feature...
# 14                    Marvel Zombies - A Zombicide Game
# 15    AnkerMake M5 3D Printer - 5X Faster Printing a...
# 16    The Wyrmwood Modular Gaming Table: Coffee & Di...
# ...

# %%
name = df["creator_prev_projects_successful"]
name.head(20)
# Out:
# 0      1
# 1      1
# 2     11
# 3      0
# 4      4
# 5      2
# 6      2
# 7      2
# 8      8
# 9      0
# 10     0
# 11     0
# 12     2
# 13     0
# 14    49
# 15     0
# 16    12
# 17     0
# 18     0
# 19     1
# Name: creator_prev_projects_successful, dtype: int64

# %%
pd.set_option('display.max_colwidth', None)
projektit_df = df[df['blurb'].str.contains('youtube', case=False, na=False)]
blurb_df = projektit_df[['blurb']]
blurb_df.head(20)
# Out:
#                                                                                                                                          blurb
# 177                                          A 5th edition campaign setting based on the hit Youtube series by Dingo Doodles and Felix Irnich.
# 2373           EyezTM by ZionEyez are HD videorecording glasses designed to share yourmemories with friends and family onFacebook and Youtube.
# 4123                                                              Four new characters for the Red Dragon Inn, based on the YouTube D&D series!
# 4364   From the creators of the Just Kidding Party YouTube channel with 1M+ followers comes this game that could make or break your friendship
# 4437                  A banned movie by Asian filmmaker & YouTube star Namewee needs funds to complete it, and let the truth out to the world!
# ...

# %%
df.nunique().sort_values()
# Out:
# state                                    2
# name_is_english                          2
# blurb_is_english                         2
# blurb_missing                            2
# name_missing                             2
# category_parent_name                    14
# currency                                15
# category_parent_id                      15
# name_len                                24
# country                                 25
# blurb_len                               38
# blurb_lang                              43
# name_lang                               44
# category_name_reduced                   54
# project_duration_days                   96
# creator_prev_projects_successful       103
# creator_prev_projects                  111
# category_name                          197
# fx_date                               4152
# deadline                              5786
# launched_date                         5800
# goal                                 12019
# ...

# %%
launched_date = df["launched_date"]
name.head(20)
# Out:
# 0      1
# 1      1
# 2     11
# 3      0
# 4      4
# 5      2
# 6      2
# 7      2
# 8      8
# 9      0
# 10     0
# 11     0
# 12     2
# 13     0
# 14    49
# 15     0
# 16    12
# 17     0
# 18     0
# 19     1
# Name: creator_prev_projects_successful, dtype: int64
